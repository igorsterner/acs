# %%
# !git clone https://github.com/igorsterner/acs
# Out:
# Cloning into 'acs'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 78 (delta 19), reused 36 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 36.07 MiB | 13.08 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# Updating files: 100% (34/34), done.

# %%
# %cd acs
# Out:
# /content/acs

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.2/349.2 kB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 MB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 72.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 120.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 55.4 MB/s eta 0:00:00
# ...

# %%
# if you needed to restart the runtime, re-run "%cd acs" from above below
# the following will take some time if the models need to be downloaded
# !PYTHONPATH=$(pwd) python acs/minimal_pairs/processing.py --lang1 de --lang2 en
# Out:
# 2025-07-17 15:20:07.810246: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752765608.076824    1717 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752765608.148899    1717 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-17 15:20:08.707673: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !PYTHONPATH=$(pwd) python acs/minimal_pairs/minimal_pairs.py
# Out:
# ID: sample_1_0
#  @USER And I said maybe etwas leiser singen, sonst ruf ich die Polizei
# *@USER And I said maybe a little leiser singen, sonst ruf ich die Polizei

# %%
# !PYTHONPATH=$(pwd) python acs/minimal_pairs/minimal_pairs.py
# Out:
# ID: sample_1_0
#  @USER And I said maybe etwas leiser singen, sonst ruf ich die Polizei
# *@USER And I said vielleicht etwas leiser singen, sonst ruf ich die Polizei

# %%
# this will load the ACS benchmark test data. Make sure you have the latest version of datasets installed on your system, and that you have requested access to the benchmark on huggingface
# !pip install -U datasets huggingface_hub fsspec --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 15.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# The token `acs` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %%
# run LLMs against the benchmark on a chosen subset of language pairs
# arguments are a space-separated list
# results should be deterministic, but there may be some small variability depending on your hardware
# !PYTHONPATH=$(pwd) python acs/analysis/llms.py --langs de-en --incremental_lms utter-project/EuroLLM-1.7B --masked_lms FacebookAI/xlm-roberta-large
# Out:
# 2025-07-17 15:58:37.700976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752767917.727623   11620 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752767917.736997   11620 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-17 15:58:37.794158: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !PYTHONPATH=$(pwd) python acs/analysis/permutation_tests.py --langs de-en --lms EuroLLM-1.7B xlm-roberta-large
# Out:
# Permutation (de-en): 100% 1/1 [00:03<00:00,  3.72s/it]
# de-en
#                    xlm-roberta-large  EuroLLM-1.7B
# xlm-roberta-large                  -        0.0019
# EuroLLM-1.7B                       -             -
#
# Means for each system:
# xlm-roberta-large: 31.4%
# EuroLLM-1.7B: 37.6%

# %%
# !PYTHONPATH=$(pwd) python acs/analysis/agreement.py
# Out:
# de-en
#   Multirater agreement: 0.57
#     Singlerater agreement 0: 0.58
#     Singlerater agreement 1: 0.69
#     Singlerater agreement 2: 0.58
#     Singlerater agreement 3: 0.52
#     Singlerater agreement 4: 0.53
# da-en
#     Singlerater agreement: 0.66
# es-en
#     Singlerater agreement: 0.70
# fr-en
#     Singlerater agreement: 0.50
# id-en
#     Singlerater agreement: 0.72
# it-en
#     Singlerater agreement: 0.73
# nl-en
#     Singlerater agreement: 0.62
# sv-en
#     Singlerater agreement: 0.64
# tr-de
#     Singlerater agreement: 0.75
# tr-en
#     Singlerater agreement: 0.71
# zh-en
#     Singlerater agreement: 0.58
